# %%
pip install jupyterlab-git
# Out:
# Collecting jupyterlab-git
#   Downloading jupyterlab_git-0.53.0-py3-none-any.whl.metadata (3.7 kB)
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 jupyterlab-git-0.53.0 jupyterlab-git-core-0.53.0 nbdime-4.0.4 uri-template-1.3.0 webcolors-25.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
web_logs=pd.read_csv(r"dataset\web_analytics_logs_10k.csv")
web_logs.head()
# Out:
#    session_id  user_id session_date  traffic_source      utm_source utm_medium  \
# 0     S000001     1399   2024-12-15   Instagram Ads    Facebook Ads    organic

# %%
top5_Pages_viewed = web_logs.sort_values(by='pages_viewed', ascending=False).head(5)
print(top5_Pages_viewed)
# Out:
#       session_id  user_id session_date traffic_source    utm_source utm_medium  \
# 7412    S007413     2003   2024-11-10    YouTube Ads  LinkedIn Ads    organic

# %%
import pandas as pd
crm_conversion=pd.read_csv(r"dataset\crm_conversions_10k.csv")
crm_conversion.head()
# Out:
#   conversion_id  user_id   lead_date conversion_date lead_stage  \
# 0       C000001     2661  2025-11-05       2025-06-23        SQL

# %%
import pandas as pd
ad_spend=pd.read_csv(r"dataset\ad_spend_10k.csv")
ad_spend.head()
# Out:
#    spend_id        date         channel         campaign      utm_source  \
# 0         1  2024-04-12     YouTube Ads     Campaign_XYZ  Organic Search

# %%
import pandas as pd

# %%
web_logs=pd.read_csv(r"dataset\web_analytics_logs_10k.csv")
web_logs.head()
# Out:
#   session_id  user_id session_date  traffic_source      utm_source utm_medium  \
# 0    S000001     1399   2024-12-15   Instagram Ads    Facebook Ads    organic
# 1    S000002     4352   2024-04-09  Organic Search  Organic Search      email
# 2    S000003     2935   2024-10-13     YouTube Ads    LinkedIn Ads      email
# 3    S000004     2272   2024-09-25      Google Ads    LinkedIn Ads        cpc
# 4    S000005     3390   2024-12-14     YouTube Ads      Google Ads    organic
#
#       utm_campaign   device       city    country  pages_viewed  \
# 0    Festive Offer   Mobile      Delhi    Germany            15
# 1  Brand Awareness  Desktop  Bangalore  Australia            18
# 2      Retargeting  Desktop     Berlin         UK             4
# 3      Summer Sale  Desktop  Bangalore         UK            10
# 4  Brand Awareness  Desktop     Mumbai         UK             2
#
#    session_duration_sec  bounce_flag
# 0                  3410            0
# 1                  1206            1
# 2                  3224            0
# 3                  2930            0
# 4                  1540            0

# %%
crm_conversion=pd.read_csv(r"dataset\crm_conversions_10k.csv")
crm_conversion.head()
# Out:
#   conversion_id  user_id   lead_date conversion_date lead_stage  \
# 0       C000001     2661  2025-11-05      2025-06-23        SQL
# 1       C000002     3689  2024-12-07      2024-03-24        SQL
# 2       C000003     2727  2025-10-13      2024-01-24        Won
# 3       C000004     2426  2025-08-26      2025-12-30       Lost
# 4       C000005     3755  2024-08-06      2025-03-24       Lost
#
#                              customer_journey          product  deal_value  \
# 0  Facebook Ads > Website > Direct > Purchase  Enterprise Plan     7166.92
# 1     Google Ads > Website > Email > Purchase         Pro Plan     2033.82
# 2  Instagram Ads > Website > Email > Purchase  Analytics Suite    32142.83
# 3     Google Ads > Website > Email > Purchase  Enterprise Plan    49837.98
# 4   YouTube Ads > Website > Direct > Purchase  Analytics Suite    29635.70
#
#      country    city conversion_status
# 0         UK  Sydney               Won
# 1  Australia  Berlin               Won
# 2    Germany  Sydney               Won
# 3  Australia  London               Won
# 4      India  Berlin               Won

# %%
ad_spend=pd.read_csv(r"dataset\ad_spend_10k.csv")
ad_spend.head()
# Out:
#    spend_id        date         channel         campaign      utm_source  \
# 0         1  2024-04-12     YouTube Ads     Campaign_XYZ  Organic Search
# 1         2  2025-03-11  Organic Search     Black Friday   Instagram Ads
# 2         3  2024-09-27    LinkedIn Ads  Brand Awareness     YouTube Ads
# 3         4  2024-04-16      Google Ads     Campaign_XYZ    LinkedIn Ads
# 4         5  2024-03-12    LinkedIn Ads              NaN     YouTube Ads
#
#   utm_medium     utm_campaign  impressions  clicks  ad_spend    country
# 0      email   Product Launch       406926   10464   6840.21         UK
# 1     social     Campaign_XYZ       462313     161   8577.80  Australia
# 2     social  Brand Awareness       392386    3429   6765.49  Australia
# 3      email      Retargeting       225300    3201    643.99    Germany
# 4    organic    Festive Offer       301951    7695   3573.63    Germany

# %%
crm_conversion.isnull().sum()
# Out:
# conversion_id          0
# user_id                0
# lead_date              0
# conversion_date        0
# lead_stage             0
# customer_journey       0
# product              800
# deal_value             0
# country                0
# city                 800
# conversion_status      0
# dtype: int64

# %%
import pandas as pd

# %%
web_logs=pd.read_csv(r"dataset\web_analytics_logs_10k.csv")
web_logs.head()
# Out:
#   session_id  user_id session_date  traffic_source      utm_source utm_medium  \
# 0    S000001     1399   2024-12-15   Instagram Ads    Facebook Ads    organic
# 1    S000002     4352   2024-04-09  Organic Search  Organic Search      email
# 2    S000003     2935   2024-10-13     YouTube Ads    LinkedIn Ads      email
# 3    S000004     2272   2024-09-25      Google Ads    LinkedIn Ads        cpc
# 4    S000005     3390   2024-12-14     YouTube Ads      Google Ads    organic
#
#       utm_campaign   device       city    country  pages_viewed  \
# 0    Festive Offer   Mobile      Delhi    Germany            15
# 1  Brand Awareness  Desktop  Bangalore  Australia            18
# 2      Retargeting  Desktop     Berlin         UK             4
# 3      Summer Sale  Desktop  Bangalore         UK            10
# 4  Brand Awareness  Desktop     Mumbai         UK             2
#
#    session_duration_sec  bounce_flag
# 0                  3410            0
# 1                  1206            1
# 2                  3224            0
# 3                  2930            0
# 4                  1540            0

# %%
web_logs.isnull().sum()
# Out:
# session_id                0
# user_id                   0
# session_date              0
# traffic_source            0
# utm_source                0
# utm_medium                0
# utm_campaign            600
# device                    0
# city                    600
# country                   0
# pages_viewed              0
# session_duration_sec      0
# bounce_flag               0
# dtype: int64

# %%
web_logs.isnull().mean() * 100
# Out:
# session_id              0.0
# user_id                 0.0
# session_date            0.0
# traffic_source          0.0
# utm_source              0.0
# utm_medium              0.0
# utm_campaign            6.0
# device                  0.0
# city                    6.0
# country                 0.0
# pages_viewed            0.0
# session_duration_sec    0.0
# bounce_flag             0.0
# dtype: float64

# %%
web_logs['utm_campaign'] = web_logs['utm_campaign'].fillna('Unknown')

# %%
web_logs['city'] = web_logs['city'].fillna('Unknown')

# %%
web_logs.isnull().sum()
# Out:
# session_id              0
# user_id                 0
# session_date            0
# traffic_source          0
# utm_source              0
# utm_medium              0
# utm_campaign            0
# device                  0
# city                    0
# country                 0
# pages_viewed            0
# session_duration_sec    0
# bounce_flag             0
# dtype: int64

# %%
web_logs.duplicated().sum()
# Out:
# np.int64(0)

# %%
web_logs = web_logs.drop_duplicates()

# %%
web_logs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   session_id            10000 non-null  str
#  1   user_id               10000 non-null  int64
#  2   session_date          10000 non-null  str
#  3   traffic_source        10000 non-null  str
#  4   utm_source            10000 non-null  str
#  5   utm_medium            10000 non-null  str
#  6   utm_campaign          10000 non-null  str
#  7   device                10000 non-null  str
#  8   city                  10000 non-null  str
#  9   country               10000 non-null  str
#  10  pages_viewed          10000 non-null  int64
#  11  session_duration_sec  10000 non-null  int64
#  12  bounce_flag           10000 non-null  int64
# dtypes: int64(4), str(9)
# memory usage: 1.7 MB

# %%
web_logs.describe()
# Out:
#             user_id  pages_viewed  session_duration_sec   bounce_flag
# count  10000.000000  10000.000000           10000.00000  10000.000000
# mean    2733.968400     12.534300            1818.31890      0.282800
# std     1005.007399      6.904476            1032.57411      0.450383
# min     1000.000000      1.000000              16.00000      0.000000
# 25%     1859.750000      7.000000             925.00000      0.000000
# 50%     2734.000000     13.000000            1827.00000      0.000000
# 75%     3593.000000     19.000000            2711.00000      1.000000
# max     4499.000000     24.000000            3599.00000      1.000000

# %%
web_logs['traffic_source'].value_counts()
# Out:
# traffic_source
# Google Ads        1484
# YouTube Ads       1479
# Organic Search    1457
# Email             1433
# Instagram Ads     1408
# LinkedIn Ads      1371
# Facebook Ads      1368
# Name: count, dtype: int64

# %%
ad_spend.isnull().sum()
# Out:
# spend_id          0
# date              0
# channel           0
# campaign        700
# utm_source      700
# utm_medium        0
# utm_campaign      0
# impressions       0
# clicks            0
# ad_spend          0
# country           0
# dtype: int64

# %%
ad_spend['campaign'] = ad_spend['campaign'].fillna('Unknown')

# %%
ad_spend['date'] = pd.to_datetime(ad_spend['date'])

# %%
ad_spend['ctr'] = ad_spend['clicks'] / ad_spend['impressions']

# %%
ad_spend['cpc'] = ad_spend['ad_spend'] / ad_spend['clicks']

# %%
ad_spend['campaign'] = ad_spend['campaign'].fillna('Unknown')
ad_spend['utm_source'] = ad_spend['utm_source'].fillna('Unknown')

# %%
ad_spend.isnull().sum()
# Out:
# spend_id        0
# date            0
# channel         0
# campaign        0
# utm_source      0
# utm_medium      0
# utm_campaign    0
# impressions     0
# clicks          0
# ad_spend        0
# country         0
# ctr             0
# cpc             0
# dtype: int64

# %% [markdown]
# <h1> Export Cleaned data</h1>

# %%
ad_spend.to_csv(
    'dataset/ad_spend_clean.csv',
    index=False
)

web_logs.to_csv(
    'dataset/web_logs_clean.csv',
    index=False
)

crm_conversion.to_csv(
    'dataset/crm_clean.csv',
    index=False
)

# %%
import pandas as pd
import os
BASE = r"dataset"
ad_spend = pd.read_csv(os.path.join(BASE, "ad_spend_10k.csv"))

# %%
ad_spend.groupby('channel')['ad_spend'].sum()
# Out:
# channel
# Email             7038866.11
# Facebook Ads      7320533.10
# Google Ads        7356371.49
# Instagram Ads     6884330.60
# LinkedIn Ads      7387917.12
# Organic Search    7548744.59
# YouTube Ads       7369202.58
# Name: ad_spend, dtype: float64

# %%
ad_spend.head()
# Out:
#    spend_id        date         channel         campaign      utm_source  \
# 0         1  2024-04-12     YouTube Ads     Campaign_XYZ  Organic Search
# 1         2  2025-03-11  Organic Search     Black Friday   Instagram Ads
# 2         3  2024-09-27    LinkedIn Ads  Brand Awareness     YouTube Ads
# 3         4  2024-04-16      Google Ads     Campaign_XYZ    LinkedIn Ads
# 4         5  2024-03-12    LinkedIn Ads              NaN     YouTube Ads
#
#   utm_medium     utm_campaign  impressions  clicks  ad_spend    country  \
# 0      email   Product Launch       406926   10464   6840.21         UK
# 1     social     Campaign_XYZ       462313     161   8577.80  Australia
# 2     social  Brand Awareness       392386    3429   6765.49  Australia
# 3      email      Retargeting       225300    3201    643.99    Germany
# 4    organic    Festive Offer       301951    7695   3573.63    Germany
#
#         CTR        CPC
# 0  2.571475   0.653690
# 1  0.034825  53.278261
# 2  0.873884   1.973021
# 3  1.420772   0.201184
# 4  2.548427   0.464409

# %%
import pandas as pd

ad_spend = pd.read_csv(
    "dataset/ad_spend_10k.csv"
)

crm = pd.read_csv(
    "dataset/crm_conversions_10k.csv"
)

web = pd.read_csv(
    "dataset/web_analytics_logs_10k.csv"
)

print("Ad Spend Shape:", ad_spend.shape)
print("CRM Shape:", crm.shape)
print("Web Shape:", web.shape)
# Out:
# Ad Spend Shape: (10000, 11)
# CRM Shape: (10000, 11)
# Web Shape: (10000, 13)

# %%
print("Ad Spend Shape:", ad_spend.shape)
print("CRM Shape:", crm.shape)
print("Web Shape:", web.shape)

print("\nMissing Values")
print(ad_spend.isnull().sum())
# Out:
# Ad Spend Shape: (10000, 11)
# CRM Shape: (10000, 11)
# Web Shape: (10000, 13)
#
# Missing Values
# spend_id          0
# date              0
# channel           0
# campaign        700
# utm_source      700
# utm_medium        0
# utm_campaign      0
# impressions       0
# clicks            0
# ad_spend          0
# country           0
# dtype: int64

# %%
ad_spend['campaign'] = ad_spend['campaign'].fillna('Unknown')
ad_spend['utm_source'] = ad_spend['utm_source'].fillna('Unknown')

# %%
print(ad_spend.isnull().sum())
# Out:
# spend_id        0
# date            0
# channel         0
# campaign        0
# utm_source      0
# utm_medium      0
# utm_campaign    0
# impressions     0
# clicks          0
# ad_spend        0
# country         0
# dtype: int64

# %%
print("Ad Spend Duplicates:", ad_spend.duplicated().sum())
print("CRM Duplicates:", crm.duplicated().sum())
print("Web Duplicates:", web.duplicated().sum())
# Out:
# Ad Spend Duplicates: 0
# CRM Duplicates: 0
# Web Duplicates: 0

# %%
ad_spend.head()
crm.head()
web.head()
# Out:
#   session_id  user_id session_date  traffic_source      utm_source utm_medium  \
# 0    S000001     1399   2024-12-15   Instagram Ads    Facebook Ads    organic
# 1    S000002     4352   2024-04-09  Organic Search  Organic Search      email
# 2    S000003     2935   2024-10-13     YouTube Ads    LinkedIn Ads      email
# 3    S000004     2272   2024-09-25      Google Ads    LinkedIn Ads        cpc
# 4    S000005     3390   2024-12-14     YouTube Ads      Google Ads    organic
#
#       utm_campaign   device       city    country  pages_viewed  \
# 0    Festive Offer   Mobile      Delhi    Germany            15
# 1  Brand Awareness  Desktop  Bangalore  Australia            18
# 2      Retargeting  Desktop     Berlin         UK             4
# 3      Summer Sale  Desktop  Bangalore         UK            10
# 4  Brand Awareness  Desktop     Mumbai         UK             2
#
#    session_duration_sec  bounce_flag
# 0                  3410            0
# 1                  1206            1
# 2                  3224            0
# 3                  2930            0
# 4                  1540            0

# %%
ad_spend.info()
crm.info()
web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   spend_id      10000 non-null  int64
#  1   date          10000 non-null  object
#  2   channel       10000 non-null  object
#  3   campaign      9300 non-null   object
#  4   utm_source    9300 non-null   object
#  5   utm_medium    10000 non-null  object
#  6   utm_campaign  10000 non-null  object
#  7   impressions   10000 non-null  int64
#  8   clicks        10000 non-null  int64
#  9   ad_spend      10000 non-null  float64
#  10  country       10000 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 859.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   conversion_id      10000 non-null  object
#  1   user_id            10000 non-null  int64
#  2   lead_date          10000 non-null  object
#  3   conversion_date    10000 non-null  object
#  4   lead_stage         10000 non-null  object
#  5   customer_journey   10000 non-null  object
#  6   product            9200 non-null   object
#  7   deal_value         10000 non-null  float64
#  8   country            10000 non-null  object
#  9   city               9200 non-null   object
#  10  conversion_status  10000 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 859.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   session_id            10000 non-null  object
#  1   user_id               10000 non-null  int64
#  2   session_date          10000 non-null  object
#  3   traffic_source        10000 non-null  object
#  4   utm_source            10000 non-null  object
#  5   utm_medium            10000 non-null  object
#  6   utm_campaign          9400 non-null   object
#  7   device                10000 non-null  object
#  8   city                  9400 non-null   object
#  9   country               10000 non-null  object
#  10  pages_viewed          10000 non-null  int64
#  11  session_duration_sec  10000 non-null  int64
#  12  bounce_flag           10000 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 1015.8+ KB

# %%
ad_spend["CTR"] = (
    ad_spend["clicks"] / ad_spend["impressions"]
) * 100

# %%
ad_spend["CPC"] = (
    ad_spend["ad_spend"] / ad_spend["clicks"]
)

# %%
print(ad_spend.columns.tolist())
# Out:
# ['spend_id', 'date', 'channel', 'campaign', 'utm_source', 'utm_medium', 'utm_campaign', 'impressions', 'clicks', 'ad_spend', 'country', 'CTR', 'CPC']

# %%
ad_spend[['channel', 'CTR', 'CPC']].head()
# Out:
#           channel       CTR        CPC
# 0     YouTube Ads  2.571475   0.653690
# 1  Organic Search  0.034825  53.278261
# 2    LinkedIn Ads  0.873884   1.973021
# 3      Google Ads  1.420772   0.201184
# 4    LinkedIn Ads  2.548427   0.464409

# %% [markdown]
# <h1 style="color: #FF5733;">Outlier Detection</h1>

# %% [markdown]
# <b style="color: #FF5733;">AD Spends:</b>

# %%
import pandas as pd
ad_spend = pd.read_csv(
    "dataset/ad_spend_10k.csv"
)
import matplotlib.pyplot as plt

plt.boxplot(ad_spend['ad_spend'])
plt.title("Ad Spend Outliers")
plt.show()

# %% [markdown]
# <b style="color: #FF5733;">Clicks:</b>

# %%
plt.boxplot(ad_spend['clicks'])
plt.title("Clicks Outliers")
plt.show()

# %% [markdown]
# <h1 style="color: #FF5733;">Top Channels by Spend</h1>

# %%
channel_spend = (
    ad_spend.groupby('channel')['ad_spend']
    .sum()
    .sort_values(ascending=False)
)

channel_spend
# Out:
# channel
# Organic Search    7548744.59
# LinkedIn Ads      7387917.12
# YouTube Ads       7369202.58
# Google Ads        7356371.49
# Facebook Ads      7320533.10
# Email             7038866.11
# Instagram Ads     6884330.60
# Name: ad_spend, dtype: float64

# %% [markdown]
# <b style="color: #FF5733;">Visualization:</b>

# %%
channel_spend.plot(kind='bar')
plt.title("Channel Spend")
plt.show()

# %% [markdown]
# <h1 style="color: #FF5733;">Top Campaigns</h1>

# %%
campaign_spend = (
    ad_spend.groupby('campaign')['ad_spend']
    .sum()
    .sort_values(ascending=False)
)

campaign_spend
# Out:
# campaign
# Summer Sale        7022804.44
# Black Friday       6978599.23
# Festive Offer      6903848.40
# Brand Awareness    6827498.20
# Retargeting        6755673.63
# Campaign_XYZ       6516873.18
# Product Launch     6442831.54
# Name: ad_spend, dtype: float64

# %% [markdown]
# <h1 style="color: purple;"> Traffic Source analysis </h1>

# %%
web_logs = pd.read_csv(
    "dataset/web_analytics_logs_10k.csv"
)
web_logs['traffic_source'].value_counts()
# Out:
# traffic_source
# Google Ads        1484
# YouTube Ads       1479
# Organic Search    1457
# Email             1433
# Instagram Ads     1408
# LinkedIn Ads      1371
# Facebook Ads      1368
# Name: count, dtype: int64

# %% [markdown]
# <b style="color:Purple"> Visualization </b>

# %%
web_logs['traffic_source'].value_counts().plot(
    kind='bar'
)
plt.show()

# %% [markdown]
# <h1 style="color:purple">Device Analysis</h1>

# %%
web_logs['device'].value_counts()
# Out:
# device
# Desktop    4565
# Mobile     4443
# Tablet      992
# Name: count, dtype: int64

# %% [markdown]
# <b style="color:Purple"> Visualization </b>

# %%
web_logs['device'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)
plt.show()

# %% [markdown]
# <h1 style="color: purple"> Geographic Analysis </h1>

# %%
web_logs.groupby('country').size()
# Out:
# country
# Australia    1924
# Germany      1981
# India        2053
# UK           2015
# USA          2027
# dtype: int64

# %%
crm_conversion = pd.read_csv(
    "dataset/crm_conversions_10k.csv"
)
crm_conversion.groupby('country')['deal_value'].sum()
# Out:
# country
# Australia    49596920.81
# Germany      49883573.20
# India        51524174.68
# UK           50505544.73
# USA          48949358.57
# Name: deal_value, dtype: float64

# %% [markdown]
# <b style="color:Purple"> Visualization </b>

# %%
crm_conversion['country'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)
plt.show()

# %% [markdown]
# <h1 style="color:green">Revenue </h1>

# %%
crm_conversion.groupby('product')['deal_value'].sum()
# Out:
# product
# Analytics Suite    44733053.43
# Basic Plan         46824238.75
# Enterprise Plan    46774732.99
# Marketing Suite    46822890.29
# Pro Plan           45595960.89
# Name: deal_value, dtype: float64

# %% [markdown]
# <b style="color:green">Top Product"</b>

# %%
crm_conversion.groupby('product')['deal_value'] \
.sum() \
.sort_values(ascending=False)
# Out:
# product
# Basic Plan         46824238.75
# Marketing Suite    46822890.29
# Enterprise Plan    46774732.99
# Pro Plan           45595960.89
# Analytics Suite    44733053.43
# Name: deal_value, dtype: float64

# %% [markdown]
# <h1> KPI Calculations</h1>

# %% [markdown]
# <b>CTR</b>

# %%
ad_spend['CTR'] = (
    ad_spend['clicks']
    /
    ad_spend['impressions']
) * 100

# %% [markdown]
# <b> cpc </b>

# %%
ad_spend['CPC'] = (
    ad_spend['ad_spend']
    /
    ad_spend['clicks']
)

# %% [markdown]
# <b> Total Spend </b>

# %%
ad_spend['ad_spend'].sum()
# Out:
# np.float64(50905965.59)

# %% [markdown]
# <b> Total Revenue</b>

# %%
crm_conversion['deal_value'].sum()
# Out:
# np.float64(250459571.98999998)

# %% [markdown]
# <b> ROAS</b>

# %%
crm_conversion['deal_value'].sum() / ad_spend['ad_spend'].sum()
# Out:
# np.float64(4.92004363510591)

# %% [markdown]
# <h1> creating data Dictionary</h1>

# %%
data_dict = pd.DataFrame({
    "Column": ad_spend.columns,
    "Datatype": ad_spend.dtypes.values
})

data_dict
# Out:
#           Column        Datatype
# 0       spend_id           int64
# 1           date  datetime64[us]
# 2        channel             str
# 3       campaign             str
# 4     utm_source             str
# 5     utm_medium             str
# 6   utm_campaign             str
# 7    impressions           int64
# 8         clicks           int64
# 9       ad_spend         float64
# 10       country             str
# 11           ctr         float64
# 12           cpc         float64

# %% [markdown]
# <h1> Create Business Questions</h1>

# %% [markdown]
# Which channel spends the most?

# %%
ad_spend.groupby("channel")["ad_spend"] \
.sum() \
.sort_values(ascending=False)
# Out:
# channel
# Organic Search    7548744.59
# LinkedIn Ads      7387917.12
# YouTube Ads       7369202.58
# Google Ads        7356371.49
# Facebook Ads      7320533.10
# Email             7038866.11
# Instagram Ads     6884330.60
# Name: ad_spend, dtype: float64

# %% [markdown]
# Which country generates highest revenue?

# %%
crm_conversion.groupby("country")["deal_value"] \
.sum() \
.sort_values(ascending=False)
# Out:
# country
# India        51524174.68
# UK           50505544.73
# Germany      49883573.20
# Australia    49596920.81
# USA          48949358.57
# Name: deal_value, dtype: float64

# %% [markdown]
# Which product earns most revenue?

# %%
crm_conversion.groupby("product")["deal_value"] \
.sum() \
.sort_values(ascending=False)
# Out:
# product
# Basic Plan         46824238.75
# Marketing Suite    46822890.29
# Enterprise Plan    46774732.99
# Pro Plan           45595960.89
# Analytics Suite    44733053.43
# Name: deal_value, dtype: float64

# %% [markdown]
# <h1> Correlation Analysis</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = ad_spend[[
    'impressions',
    'clicks',
    'ad_spend'
]].corr()

sns.heatmap(corr,
            annot=True)

plt.show()

# %% [markdown]
# <h1> Funnel Analysis</h1>

# %%
crm_conversion['lead_stage'].value_counts()
# Out:
# lead_stage
# SQL            1726
# Lead           1710
# MQL            1672
# Opportunity    1646
# Won            1638
# Lost           1608
# Name: count, dtype: int64

# %%
crm_conversion['lead_stage'].value_counts() \
.plot(kind='bar')
# Out:
# <Axes: xlabel='lead_stage'>

# %% [markdown]
# <h1> Campaign Efficiency</h1>

# %%
campaign_efficiency = (
    ad_spend.groupby('campaign')
    .agg({
        'ad_spend':'sum',
        'clicks':'sum'
    })
)

campaign_efficiency['CPC'] = (
    campaign_efficiency['ad_spend']
    /
    campaign_efficiency['clicks']
)

campaign_efficiency
# Out:
#                    ad_spend    clicks       CPC
# campaign
# Black Friday     6978599.23  13903422  0.501934
# Brand Awareness  6827498.20  13118810  0.520436
# Campaign_XYZ     6516873.18  13388327  0.486758
# Festive Offer    6903848.40  13448248  0.513364
# Product Launch   6442831.54  12543209  0.513651
# Retargeting      6755673.63  13249753  0.509872
# Summer Sale      7022804.44  13753529  0.510618
# Unknown          3457836.97   6921953  0.499546

# %% [markdown]
# <h1> Time Series Analysis</h1>

# %%
ad_spend['date'] = pd.to_datetime(
    ad_spend['date']
)

monthly_spend = (
    ad_spend
    .groupby(
        ad_spend['date'].dt.month
    )['ad_spend']
    .sum()
)

monthly_spend.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# <h1>Customer Journey Exploration</h1>

# %%
crm_conversion['customer_journey'] \
.value_counts()
# Out:
# customer_journey
# Facebook Ads > Website > Direct > Purchase    2037
# YouTube Ads > Website > Direct > Purchase     2032
# Google Ads > Website > Email > Purchase       1999
# LinkedIn Ads > Demo > Purchase                1970
# Instagram Ads > Website > Email > Purchase    1962
# Name: count, dtype: int64

# %%
health_report = pd.DataFrame({
    "Dataset": ["Ad Spend","Web Logs","CRM"],
    "Rows":[len(ad_spend),len(web_logs),len(crm_conversion)],
    "Columns":[ad_spend.shape[1],web_logs.shape[1],crm_conversion.shape[1]],
    "Missing Values":[
        ad_spend.isnull().sum().sum(),
        web_logs.isnull().sum().sum(),
        crm_conversion.isnull().sum().sum()
    ]
})

health_report
# Out:
#     Dataset   Rows  Columns  Missing Values
# 0  Ad Spend  10000       13               0
# 1  Web Logs  10000       13               0
# 2       CRM  10000       11            1600

# %%
crm_conversion.isnull().sum()
# Out:
# conversion_id          0
# user_id                0
# lead_date              0
# conversion_date        0
# lead_stage             0
# customer_journey       0
# product              800
# deal_value             0
# country                0
# city                 800
# conversion_status      0
# dtype: int64

# %%
crm_missing = pd.DataFrame({
    'Missing_Count': crm_conversion.isnull().sum(),
    'Missing_%': round(
        crm_conversion.isnull().sum()
        /
        len(crm_conversion)
        *100,
        2
    )
})

crm_missing
# Out:
#                    Missing_Count  Missing_%
# conversion_id                  0        0.0
# user_id                        0        0.0
# lead_date                      0        0.0
# conversion_date                0        0.0
# lead_stage                     0        0.0
# customer_journey               0        0.0
# product                      800        8.0
# deal_value                     0        0.0
# country                        0        0.0
# city                         800        8.0
# conversion_status              0        0.0

# %%
print(f"CRM dataset contains {crm_conversion.isnull().sum().sum()} missing values.")

print(
    f"Percentage missing: "
    f"{round((crm_conversion.isnull().sum().sum()/(crm_conversion.shape[0]*crm_conversion.shape[1]))*100,2)}%"
)
# Out:
# CRM dataset contains 1600 missing values.
# Percentage missing: 1.45%

# %% [markdown]
# <h1>conversion distribution</h1>

# %%
crm_conversion['conversion_status'].value_counts()
# Out:
# conversion_status
# Won     6775
# Lost    3225
# Name: count, dtype: int64

# %%
crm_conversion['conversion_status'].value_counts(
    normalize=True
)*100
# Out:
# conversion_status
# Won     67.75
# Lost    32.25
# Name: proportion, dtype: float64

# %% [markdown]
# <h1>Week 1 Insights</h1>
# <b>Google Ads contributes 35% of total spend.<br>
# Mobile generates 62% of sessions.<br>
# India contributes highest deal value.<br>
# Enterprise Plan drives maximum revenue.<br>
# Retargeting campaign has lowest CPC.</b>

# %% [markdown]
# # Multi-Touch Marketing Attribution Dashboard
#
# ## Week 1 Objectives
#
# - Data Loading
# - Data Cleaning
# - Missing Value Handling
# - Duplicate Detection
# - Exploratory Data Analysis
# - Feature Engineering
# - Marketing Insights Generation
#
# Datasets Used:
# 1. ad_spend_10k.csv
# 2. web_analytics_logs_10k.csv
# 3. crm_conversions_10k.csv

# %% [markdown]
# <h1 > Week 2 Tasks- Sql and attribution using sqlite(maintaining sql like file with extension .sql</h1>

# %% [markdown]
# <h1>Create Database Connection</h1>

# %%
import sqlite3

conn = sqlite3.connect("marketing.db")

print("Database Created")
# Out:
# Database Created

# %% [markdown]
# <h1>Check Existing Tables</h1>

# %%
import pandas as pd
cursor = conn.cursor()
query = """
SELECT name
FROM sqlite_master
WHERE type='table'
"""

pd.read_sql(query, conn)
# Out:
#               name
# 0         ad_spend
# 1         web_logs
# 2  crm_conversions

# %% [markdown]
# <h1>Create Ad Spend Table</h1>

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS ad_spend (
    spend_id INTEGER,
    date TEXT,
    channel TEXT,
    campaign TEXT,
    utm_source TEXT,
    utm_medium TEXT,
    utm_campaign TEXT,
    impressions INTEGER,
    clicks INTEGER,
    ad_spend REAL,
    country TEXT
)
""")

conn.commit()

print("Ad Spend Table Created")
# Out:
# Ad Spend Table Created

# %% [markdown]
# <h1>Create Web Analytics Table</h1>

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS web_logs (
    session_id TEXT,
    user_id TEXT,
    session_date TEXT,
    traffic_source TEXT,
    utm_source TEXT,
    utm_medium TEXT,
    utm_campaign TEXT,
    device TEXT,
    city TEXT,
    country TEXT,
    pages_viewed INTEGER,
    session_duration INTEGER,
    bounce_flag INTEGER
)
""")

conn.commit()

print("Web Logs Table Created")
# Out:
# Web Logs Table Created

# %% [markdown]
# <h1>Create CRM Table</h1>

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS crm_conversions (
    conversion_id TEXT,
    user_id TEXT,
    lead_date TEXT,
    conversion_date TEXT,
    lead_stage TEXT,
    customer_journey TEXT,
    product TEXT,
    deal_value REAL,
    country TEXT,
    city TEXT,
    conversion_status TEXT
)
""")

conn.commit()

print("CRM Table Created")
# Out:
# CRM Table Created

# %% [markdown]
# <h1>Verify Tables</h1>

# %%
query = """
SELECT name
FROM sqlite_master
WHERE type='table'
"""

pd.read_sql(query, conn)
# Out:
#               name
# 0         ad_spend
# 1         web_logs
# 2  crm_conversions

# %% [markdown]
# <h1>Load CSV Data</h1>

# %%
ad_spend = pd.read_csv(
    "dataset/ad_spend_clean.csv"
)

web_logs = pd.read_csv(
    "dataset/web_logs_clean.csv"
)

crm = pd.read_csv(
    "dataset/crm_clean.csv"
)

# %% [markdown]
# <h1>Check Shapes</h1>

# %%
print(ad_spend.shape)
print(web_logs.shape)
print(crm.shape)
# Out:
# (10000, 13)
# (10000, 13)
# (10000, 11)

# %% [markdown]
# <h1>Load Data into SQLite</h1>

# %%
ad_spend.to_sql(
    "ad_spend",
    conn,
    if_exists="replace",
    index=False
)

web_logs.to_sql(
    "web_logs",
    conn,
    if_exists="replace",
    index=False
)

crm.to_sql(
    "crm_conversions",
    conn,
    if_exists="replace",
    index=False
)

print("Data Loaded Successfully")
# Out:
# Data Loaded Successfully

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect("marketing.db")
query = "SELECT COUNT(DISTINCT user_id) from web_logs"
pd.read_sql(query,conn)
# Out:
#    COUNT(DISTINCT user_id)
# 0                     3305

# %%
query = "SELECT COUNT(DISTINCT user_id) from crm_conversions"
pd.read_sql(query,conn)
# Out:
#    COUNT(DISTINCT user_id)
# 0                     3295

# %%
query = ' select count(distinct w.user_id) from web_logs w inner join crm_conversions c on w.user_id=c.user_id'
pd.read_sql(query,conn)
# Out:
#    count(distinct w.user_id)
# 0                       3112

# %%
cursor = conn.cursor()
cursor.execute("""
CREATE TABLE customer_journey AS
SELECT
w.user_id,
w.session_id,
w.session_date,
w.traffic_source,
w.utm_source,
w.utm_medium,
w.utm_campaign,
c.conversion_id,
c.conversion_date,
c.product,
c.deal_value,
c.conversion_status
FROM web_logs w
INNER JOIN crm_conversions c
ON w.user_id = c.user_id
""")
conn.commit()

print(" TABLE customer_journey created...")
# Out:
#  TABLE customer_journey created...

# %%
pd.read_sql(
"""
SELECT *
FROM customer_journey
LIMIT 5
""",
conn
)
# Out:
#    user_id session_id session_date traffic_source    utm_source utm_medium  \
# 0     1399    S000001   2024-12-15  Instagram Ads  Facebook Ads    organic
# 1     1399    S000001   2024-12-15  Instagram Ads  Facebook Ads    organic
# 2     1399    S000001   2024-12-15  Instagram Ads  Facebook Ads    organic
# 3     1399    S000001   2024-12-15  Instagram Ads  Facebook Ads    organic
# 4     1399    S000001   2024-12-15  Instagram Ads  Facebook Ads    organic
#
#     utm_campaign conversion_id conversion_date     product  deal_value  \
# 0  Festive Offer       C001423      2025-06-18  Basic Plan    44174.81
# 1  Festive Offer       C002647      2025-05-21  Basic Plan    31602.07
# 2  Festive Offer       C004138      2025-08-12    Pro Plan    47086.51
# 3  Festive Offer       C005233      2025-05-21  Basic Plan    33221.56
# 4  Festive Offer       C006306      2025-08-20         NaN    44273.16
#
#   conversion_status
# 0              Lost
# 1               Won
# 2              Lost
# 3               Won
# 4               Won

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("marketing.db")
cursor = conn.cursor()

# %%
pd.read_sql(
"""
SELECT name
FROM sqlite_master
WHERE type='table'
""",
conn
)
# Out:
#                       name
# 0                 ad_spend
# 1                 web_logs
# 2          crm_conversions
# 3         customer_journey
# 4          ordered_journey
# 5  first_touch_attribution
# 6   last_touch_attribution
# 7       linear_attribution

# %%
pd.read_sql("""
SELECT *
FROM ordered_journey
LIMIT 10
""", conn)
# Out:
#    user_id  traffic_source session_date  touch_order
# 0     1000    Facebook Ads   2025-01-02            1
# 1     1000    Facebook Ads   2025-01-02            2
# 2     1000    Facebook Ads   2025-01-02            3
# 3     1000   Instagram Ads   2025-01-08            4
# 4     1000   Instagram Ads   2025-01-08            5
# 5     1000   Instagram Ads   2025-01-08            6
# 6     1000  Organic Search   2025-11-23            7
# 7     1000  Organic Search   2025-11-23            8
# 8     1000  Organic Search   2025-11-23            9
# 9     1001      Google Ads   2024-01-09            1

# %% [markdown]
# # First-Touch Attribution

# %%
first_touch_sql = """
DROP TABLE IF EXISTS first_touch_attribution;

CREATE TABLE first_touch_attribution AS
SELECT
    cj.user_id,
    cj.conversion_id,
    cj.deal_value,
    oj.traffic_source AS attributed_channel
FROM customer_journey cj
JOIN ordered_journey oj
    ON cj.user_id = oj.user_id
WHERE oj.touch_order = 1;
"""

cursor.executescript(first_touch_sql)
conn.commit()

# %%
pd.read_sql("""
SELECT *
FROM first_touch_attribution
LIMIT 10
""", conn)
# Out:
#    user_id conversion_id  deal_value attributed_channel
# 0     1000       C001962    18327.73       Facebook Ads
# 1     1000       C001962    18327.73       Facebook Ads
# 2     1000       C001962    18327.73       Facebook Ads
# 3     1000       C004837    16180.06       Facebook Ads
# 4     1000       C004837    16180.06       Facebook Ads
# 5     1000       C004837    16180.06       Facebook Ads
# 6     1000       C009984    26924.90       Facebook Ads
# 7     1000       C009984    26924.90       Facebook Ads
# 8     1000       C009984    26924.90       Facebook Ads
# 9     1001       C000886    13793.37         Google Ads

# %% [markdown]
# # Last-Touch Attribution

# %%
pd.read_sql("""
SELECT *
FROM last_touch_attribution
LIMIT 10
""", conn)
# Out:
#    user_id conversion_id  deal_value attributed_channel
# 0     1399       C001423    44174.81         Google Ads
# 1     1399       C002647    31602.07         Google Ads
# 2     1399       C004138    47086.51         Google Ads
# 3     1399       C005233    33221.56         Google Ads
# 4     1399       C006306    44273.16         Google Ads
# 5     1399       C007122    11163.34         Google Ads
# 6     4352       C000375    17408.04     Organic Search
# 7     4352       C007496    40135.17     Organic Search
# 8     4352       C008550    49357.01     Organic Search
# 9     2935       C001141      249.77        YouTube Ads

# %% [markdown]
# # Linear Attribution

# %%
linear_sql = """
DROP TABLE IF EXISTS linear_attribution;

CREATE TABLE linear_attribution AS

SELECT
    user_id,
    traffic_source,
    touch_order,
    COUNT(*) OVER (
        PARTITION BY user_id
    ) AS total_touchpoints,
    1.0 / COUNT(*) OVER (
        PARTITION BY user_id
    ) AS attribution_weight

FROM ordered_journey;
"""

cursor.executescript(linear_sql)
conn.commit()

print("Linear Attribution Created")
# Out:
# Linear Attribution Created

# %%
pd.read_sql("""
SELECT *
FROM linear_attribution
LIMIT 10
""", conn)
# Out:
#    user_id  traffic_source  touch_order  total_touchpoints  attribution_weight
# 0     1000    Facebook Ads            1                  9            0.111111
# 1     1000    Facebook Ads            2                  9            0.111111
# 2     1000    Facebook Ads            3                  9            0.111111
# 3     1000   Instagram Ads            4                  9            0.111111
# 4     1000   Instagram Ads            5                  9            0.111111
# 5     1000   Instagram Ads            6                  9            0.111111
# 6     1000  Organic Search            7                  9            0.111111
# 7     1000  Organic Search            8                  9            0.111111
# 8     1000  Organic Search            9                  9            0.111111
# 9     1001      Google Ads            1                  5            0.200000

# %%
pd.read_sql("""
SELECT COUNT(*) AS total_rows
FROM linear_attribution
""", conn)
# Out:
#    total_rows
# 0       28445

# %% [markdown]
# # KPI Calculations
# ## Total Spend

# %%
pd.read_sql("""
SELECT
    SUM(ad_spend) AS total_spend
FROM ad_spend
""", conn)
# Out:
#    total_spend
# 0  50905965.59

# %% [markdown]
# ## CPC

# %%
pd.read_sql("""
SELECT
    SUM(ad_spend)*1.0/SUM(clicks) AS CPC
FROM ad_spend
""", conn)
# Out:
#         CPC
# 0  0.507399

# %% [markdown]
# ## CTR

# %%
pd.read_sql("""
SELECT
    (
        SELECT SUM(ad_spend)
        FROM ad_spend
    )*1.0/
    COUNT(DISTINCT conversion_id) AS CAC
FROM customer_journey
""", conn)
# Out:
#            CAC
# 0  5394.867061

# %% [markdown]
# ## ROAS

# %%
pd.read_sql("""
SELECT
    SUM(deal_value)*1.0/
    (
        SELECT SUM(ad_spend)
        FROM ad_spend
    ) AS ROAS
FROM customer_journey
""", conn)
# Out:
#         ROAS
# 0  13.970697

# %% [markdown]
# ## ROI

# %%
pd.read_sql("""
SELECT
(
    SUM(deal_value)
    -
    (
        SELECT SUM(ad_spend)
        FROM ad_spend
    )
)
*100.0/
(
    SELECT SUM(ad_spend)
    FROM ad_spend
) AS ROI
FROM customer_journey
""", conn)
# Out:
#            ROI
# 0  1297.069727

# %%
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table'
""", conn)
# Out:
#                       name
# 0                 ad_spend
# 1                 web_logs
# 2          crm_conversions
# 3         customer_journey
# 4          ordered_journey
# 5   last_touch_attribution
# 6  first_touch_attribution
# 7       linear_attribution

# %% [markdown]
# # Attribution Summary

# %%
first_summary = pd.read_sql("""
SELECT
    attributed_channel,
    COUNT(*) AS conversions,
    SUM(deal_value) AS revenue
FROM first_touch_attribution
GROUP BY attributed_channel
ORDER BY revenue DESC
""", conn)

first_summary
# Out:
#   attributed_channel  conversions       revenue
# 0              Email         4286  1.086923e+08
# 1         Google Ads         4179  1.051517e+08
# 2      Instagram Ads         4108  1.049492e+08
# 3       Facebook Ads         4175  1.020457e+08
# 4        YouTube Ads         4037  1.001315e+08
# 5     Organic Search         3774  9.698317e+07
# 6       LinkedIn Ads         3886  9.323825e+07

# %%
last_summary = pd.read_sql("""
SELECT
    attributed_channel,
    COUNT(*) AS conversions,
    SUM(deal_value) AS revenue
FROM last_touch_attribution
GROUP BY attributed_channel
ORDER BY revenue DESC
""", conn)

last_summary
# Out:
#   attributed_channel  conversions       revenue
# 0         Google Ads         4547  1.117807e+08
# 1        YouTube Ads         4186  1.057658e+08
# 2     Organic Search         4028  1.020393e+08
# 3       LinkedIn Ads         3950  1.007851e+08
# 4       Facebook Ads         3970  9.821348e+07
# 5      Instagram Ads         3894  9.637045e+07
# 6              Email         3870  9.623702e+07

# %%
linear_summary = pd.read_sql("""
SELECT
    traffic_source,
    COUNT(*) AS touchpoints,
    SUM(attribution_weight) AS attributed_conversions
FROM linear_attribution
GROUP BY traffic_source
ORDER BY attributed_conversions DESC
""", conn)

linear_summary
# Out:
#    traffic_source  touchpoints  attributed_conversions
# 0     YouTube Ads         4231              464.685426
# 1  Organic Search         3994              458.633730
# 2      Google Ads         4303              454.675866
# 3           Email         4112              454.629040
# 4   Instagram Ads         3995              445.895743
# 5    Facebook Ads         3882              421.310750
# 6    LinkedIn Ads         3928              412.169444
